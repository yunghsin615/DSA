# %% [markdown]
# # Binary Search Tree
# 二元搜尋樹：將數列排成完全二元樹，一個父節點最多有兩個子節點，父節點大於左子節點、小於右子節點，每一個節點會指向下一個節點，最後一個節點會指向 None，以這個條件去執行新增、查詢、刪除，以及修改節點的功能。
#    * 若要查詢 BST 中的一個值，首先必須先確定此值有無在 BST 中，有的話可由上往下循著去與每一個父節點與子節點比較大小去找到此值。
#    * 若要新增一個值至 BST ，會由上往下循著去與每一個父節點與子節點比較大小，最終此值會放在 BST 的最尾端（不會有子節點），而並非在中途插入新增。
#    * 若要刪除 BST 中的一個值，首先必須先確定此值有無在 BST 中，有的話可由上往下循著去與每一個父節點與子節點比較大小去找到此值，要將此值刪除，須先注意此值有無子節點，若沒有孩子，須將此值的父節點指向 None，若有孩子，須將此值的父節點指向此值的孩子，並將 BST 中的第一個父節點替換成此值的右子節點中的最小值，要注意的是，有重複之值必須重複刪除。
#    * 若要將 BST 中的一個值修改成另一個值，先進行刪除的動作，接下來再新增，刪除了幾個重複的值，就必須新增幾個新的值。

# %% [markdown]
# ```由於 BST 較難單用文字說明，因此學習歷程內並沒有詳細說明，而是以手寫的方式放在流程圖內，配合畫圖說明詳細邏輯構想與步驟。
# ```

# %% [markdown]
# # 學習歷程
# ## 原本的構想：先寫 Linked List
# 當老師在教 BST 時，請我們從 Linkes List 開始改，因爲節點連接的方式相似，但由於老師之前在教 Linked List 時，我還在寫 codesignal，並沒有進入狀況，也還沒複習好 python，我那時並沒有寫自己的 Linkes List，所以在做這次的作業前，我先試寫了 Linkes List 如下。
#
# 我並沒有寫完，在完成 search 之後，我發現時間好像不夠，於是我直接著手開始寫 BST，雖然不知道 Linkes List 有沒有寫對，也沒有完成，但節點連接的概念我已經理解了，還是有助於寫 BST。

# %%
def __init__(self):
    self.head = None
    self.n = 0
    
def search(self,index: int) -> int:
    if head == None:
        return -1
    if index >= len(list):
        return -1
    if index == 1:
        return self.val
    p = self.next
    i = 1
    while p != None:
        if i == index:
            return p.val
        p = p.next
        i += 1
        return -1

# %% [markdown]
# ## 著手寫 BST：insert 與 serch
# 我是先寫 serch，於是我找到了以下網站，理解他的程式碼並搞清楚大致方向後，直接著手開始自己寫，與之前的寫作業方式不一樣（先理解別人的程式碼，再想辦法修改成自己能完全理解的版本），沒想到寫完 search 輸入測資後竟然沒有出現 error！對我來說這是很大的進步，從第一次的作業以來，慢慢熟悉了判斷式、迴圈的用法，到現在終於能自己運用了。
#    * [search 參考網站](https://www.tutorialspoint.com/python_data_structure/python_binary_search_tree.htm)

# %%
def search(self,root,target):
    if target < root.val:
        if root.left == None:
            return None
        else:
            p = root.left 
            return self.search(p,target)
    elif target > root.val:
        if root.right == None:
            return None
        else:
            p = root.right
            return self.search(p,target)
    else:
        return True

# %% [markdown]
# 後來發現找到 target 後要 return target才會符合助教的格式，因此將最後一行改成 return root。
#
# 運用與 search 相同的比大小、呼叫函式概念，完成了 insert，輸入自己的測資也沒有出現 error！但一開始未考慮到若樹中已有與欲加入之測資相同之值時該如何解決，參考助教的作業 ppt 後發現相同之值放在左子節點就好，於是在程式碼中的第一個 if 判斷式的「<」後面加上 「＝」，即真正完成了 insert。

# %%
def insert(self,root,val):
    if val <= root.val:
        if root.left == None:
            root.left = TreeNode(val)
        else:
            p = root.left
            self.insert(p,val)
    else:
        if root.right == None:
            root.right = TreeNode(val)
        else:
            p = root.right
            self.insert(p,val)

# %% [markdown]
# ## 著手寫 BST：delete
# delete 是花我最多時間與精力的功能，耗費了整整三天的時間才變成現在的模樣！
#
# 由於 BST 中的節點若要被刪掉，必須由欲刪除節點的上一個節點指向他的下一個節點，若欲刪除節點有子節點，還得將最靠近root的值替換上去，而更改整個結構，因此非常複雜，最初的 delete 我透過理解其他網站上的程式碼（以下為參考網站），很快就自己寫好了，同樣運用 search 的概念去找到欲刪除之值，只是測試不同測資後，一直出現 error，必須為了測資再去更改，也發現了其實大部分網站上的程式碼都不是完整的，輸入各種可能的測值並不會全對，於是我後來修改都是用自己的想法而原創產生的。
#    * [delete 參考網站 1](https://www.geeksforgeeks.org/binary-search-tree-set-2-delete/)
#    * [delete 參考網站 2](https://www.twblogs.net/a/5d4e2980bd9eee541c310dd4)
#    * [delete 參考網站 3](https://www.itread01.com/content/1542339850.html)
#
#
# 一開始先將 target 分成四種，分別為沒有小孩、有一個左小孩、有一個右小孩、有兩個小孩。
#    * 讓沒有小孩的 target 的父節點指向 None。
#    * 讓有一個左小孩的 target 之值換成左小孩中最大的數。
#    * 讓有一個右小孩的 target 之值換成右小孩中最小的數。
#    * 讓有兩個小孩的 target 之值換成右小孩中最小的數。
#
# 發現例外後不斷更改原本的程式碼，最後程式碼由 20 幾行增加至 128 行。

# %%
def delete(self,root,target):
    i = root
    parent = root
    while target != root.val: #找parent、x
        parent = root
        if target < root.val:
            if root.left == None:
                break
            else:
                root = root.left 
        elif target > root.val:
            if root.right == None:
                break
            else:
                root = root.right
                    
    if target == root.val:
        if root.left == None and root.right == None: #target沒有孩子
            if parent.val < root.val:
                parent.right = None
            elif parent.val > root.val:
                parent.left = None
            else:
                del root.val
        elif root.left == None and root.right != None: #target沒有左孩子 有右孩子
            if parent.val < root.val:
                parent.right = root.right
            elif parent.val > root.val:
                parent.left = root.right
            else:
                parent = root
                root = root.right
                if root.left == None and root.right == None: #target.right沒有孩子
                    parent.val = root.val
                    parent.right = None
                elif root.left == None and root.right != None: #target.right沒有左孩子 有右孩子
                    parent.val = root.val
                    parent.right = root.right
                elif root.left != None and root.right == None: #target.right有左孩子 沒有右孩子
                    temp = root
                    while temp.left != None:
                        Minparent = temp
                        temp = Minparent.left

                    Min = temp
                    parent.val = Min.val
                    if Min.right != None:
                            Minparent.left = Min.right
                    else:
                        Minparent.left = None
                else: #target.right有兩個孩子
                    temp = root
                    while temp.left != None:
                        Minparent = temp
                        temp = Minparent.left

                    Min = temp
                    parent.val = Min.val
                    if Min.right != None:
                        Minparent.left = Min.right
                    else:
                        Minparent.left = None
                        
                        
        elif root.left != None and root.right == None: #target有左孩子 沒有右孩子
            if parent.val < root.val:
                parent.right = root.left
            elif parent.val > root.val:
                parent.left = root.left
            else:
                parent = root
                root = root.left
                if root.left == None and root.right == None: #target.left沒有孩子
                    parent.val = root.val
                    parent.left = None
                elif root.left == None and root.right != None: #target.left沒有左孩子 有右孩子
                    temp = root
                    while temp.right != None:
                        Maxparent = temp
                        temp = Maxparent.right

                    Max = temp
                    parent.val = Max.val
                    if Max.left != None:
                        Minparent.right = Max.left
                    else:
                        Maxparent.right = None
                elif root.left != None and root.right == None: #target.left有左孩子 沒有右孩子
                    parent.val = root.val
                    parent.left = root.left
                else: #target.left有兩個孩子
                    temp = root
                    while temp.right != None:
                        Maxparent = temp
                        temp = Maxparent.right

                    Max = temp
                    parent.val = Max.val
                    if Max.left != None:
                        Maxparent.right = Max.left
                    else:
                        Maxparent.right = None

        else: #target有兩個孩子
            temp = root.right
            if temp.left == None:
                Minparent = root

                Min = temp
                root.val = Min.val
                if Min.right != None:
                    Minparent.right = Min.right
                else:
                    Minparent.right = None
            else:
                while temp.left != None:
                    Minparent = temp
                    temp = Minparent.left

                Min = temp
                root.val = Min.val
                if Min.right != None:
                    Minparent.left = Min.right
                else:
                    Minparent.left = None
        self.delete(i,target)
    return i

# %% [markdown]
# ## 著手寫 BST：modify
# 原本是想呼叫 delete 函式與 insert 函式即可，後來發現 delete 函式可一次刪除所有重複的值，insert 函式卻無法一次新增重複的值。
#
# 於是我複製 delete 函式中的程式碼，並在前面新增了重複值個數的變數以及 while 迴圈，再用 for 迴圈跑重複值個數次 insert 函式，卻又陷入了無限迴圈，如以下程式碼。

# %%
def modify(self,root,target,new_val):
    #self.delete(root,target)
    repeat = 0
    i = root
    while self.search(root,target) != None:
        parent = root
        while target != root.val: #找parent、x
            parent = root
            if target < root.val:
                if root.left == None:
                    break
                else:
                    root = root.left 
            elif target > root.val:
                if root.right == None:
                    break
                else:
                    root = root.right

        if target == root.val:
            if root.left == None and root.right == None: #target沒有孩子
                if parent.val < root.val:
                    parent.right = None
                elif parent.val > root.val:
                    parent.left = None
                else:
                    del root.val
            elif root.left == None and root.right != None: #target沒有左孩子 有右孩子
                if parent.val < root.val:
                    parent.right = root.right
                elif parent.val > root.val:
                    parent.left = root.right
                else:
                    parent = root
                    root = root.right
                    if root.left == None and root.right == None: #target.right沒有孩子
                        parent.val = root.val
                        parent.right = None
                    elif root.left == None and root.right != None: #target.right沒有左孩子 有右孩子
                        parent.val = root.val
                        parent.right = root.right
                    elif root.left != None and root.right == None: #target.right有左孩子 沒有右孩子
                        temp = root
                        while temp.left != None:
                            Minparent = temp
                            temp = Minparent.left

                        Min = temp
                        parent.val = Min.val
                        if Min.right != None:
                            Minparent.left = Min.right
                        else:
                            Minparent.left = None
                    else: #target.right有兩個孩子
                        temp = root
                        while temp.left != None:
                            Minparent = temp
                            temp = Minparent.left

                        Min = temp
                        parent.val = Min.val
                        if Min.right != None:
                            Minparent.left = Min.right
                        else:
                            Minparent.left = None


            elif root.left != None and root.right == None: #target有左孩子 沒有右孩子
                if parent.val < root.val:
                    parent.right = root.left
                elif parent.val > root.val:
                    parent.left = root.left
                else:
                    parent = root
                    root = root.left
                    if root.left == None and root.right == None: #target.left沒有孩子
                        parent.val = root.val
                        parent.left = None
                    elif root.left == None and root.right != None: #target.left沒有左孩子 有右孩子
                        temp = root
                        while temp.right != None:
                            Maxparent = temp
                            temp = Maxparent.right

                        Max = temp
                        parent.val = Max.val
                        if Max.left != None:
                            Minparent.right = Max.left
                        else:
                            Maxparent.right = None
                    elif root.left != None and root.right == None: #target.left有左孩子 沒有右孩子
                        parent.val = root.val
                        parent.left = root.left
                    else: #target.left有兩個孩子
                        temp = root
                        while temp.right != None:
                            Maxparent = temp
                            temp = Maxparent.right

                        Max = temp
                        parent.val = Max.val
                        if Max.left != None:
                            Maxparent.right = Max.left
                        else:
                            Maxparent.right = None

            else: #target有兩個孩子
                temp = root.right
                if temp.left == None:
                    Minparent = root

                    Min = temp
                    root.val = Min.val
                    if Min.right != None:
                        Minparent.right = Min.right
                    else:
                        Minparent.right = None
                else:
                    while temp.left != None:
                        Minparent = temp
                        temp = Minparent.left

                    Min = temp
                    root.val = Min.val
                    if Min.right != None:
                        Minparent.left = Min.right
                    else:
                        Minparent.left = None
            repeat += 1
                
    for j in range(repeat):
        self.insert(i,new_val)


    return i

# %% [markdown]
# 最後我改成跑一次 delete 就跑一次 insert，修改重複值的數值，就成功了！！！

# %%
def modify(self,root,target,new_val):
    #self.delete(root,target)
    i = root
    while self.search(root,target) != None:
        parent = root
        while target != root.val: #找parent、x
            parent = root
            if target < root.val:
                if root.left == None:
                    break
                else:
                    root = root.left 
            elif target > root.val:
                if root.right == None:
                    break
                else:
                    root = root.right

        if target == root.val:
            if root.left == None and root.right == None: #target沒有孩子
                if parent.val < root.val:
                    parent.right = None
                elif parent.val > root.val:
                    parent.left = None
                else:
                    del root.val
            elif root.left == None and root.right != None: #target沒有左孩子 有右孩子
                if parent.val < root.val:
                    parent.right = root.right
                elif parent.val > root.val:
                    parent.left = root.right
                else:
                    parent = root
                    root = root.right
                    if root.left == None and root.right == None: #target.right沒有孩子
                        parent.val = root.val
                        parent.right = None
                    elif root.left == None and root.right != None: #target.right沒有左孩子 有右孩子
                        parent.val = root.val
                        parent.right = root.right
                    elif root.left != None and root.right == None: #target.right有左孩子 沒有右孩子
                        temp = root
                        while temp.left != None:
                            Minparent = temp
                            temp = Minparent.left

                        Min = temp
                        parent.val = Min.val
                        if Min.right != None:
                            Minparent.left = Min.right
                        else:
                            Minparent.left = None
                    else: #target.right有兩個孩子
                        temp = root
                        while temp.left != None:
                            Minparent = temp
                            temp = Minparent.left

                        Min = temp
                        parent.val = Min.val
                        if Min.right != None:
                            Minparent.left = Min.right
                        else:
                            Minparent.left = None


            elif root.left != None and root.right == None: #target有左孩子 沒有右孩子
                if parent.val < root.val:
                    parent.right = root.left
                elif parent.val > root.val:
                    parent.left = root.left
                else:
                    parent = root
                    root = root.left
                    if root.left == None and root.right == None: #target.left沒有孩子
                        parent.val = root.val
                        parent.left = None
                    elif root.left == None and root.right != None: #target.left沒有左孩子 有右孩子
                        temp = root
                        while temp.right != None:
                            Maxparent = temp
                            temp = Maxparent.right

                        Max = temp
                        parent.val = Max.val
                        if Max.left != None:
                            Minparent.right = Max.left
                        else:
                            Maxparent.right = None
                    elif root.left != None and root.right == None: #target.left有左孩子 沒有右孩子
                        parent.val = root.val
                        parent.left = root.left
                    else: #target.left有兩個孩子
                        temp = root
                        while temp.right != None:
                            Maxparent = temp
                            temp = Maxparent.right

                        Max = temp
                        parent.val = Max.val
                        if Max.left != None:
                            Maxparent.right = Max.left
                        else:
                            Maxparent.right = None

            else: #target有兩個孩子
                temp = root.right
                if temp.left == None:
                    Minparent = root

                    Min = temp
                    root.val = Min.val
                    if Min.right != None:
                        Minparent.right = Min.right
                    else:
                        Minparent.right = None
                else:
                    while temp.left != None:
                        Minparent = temp
                        temp = Minparent.left

                    Min = temp
                    root.val = Min.val
                    if Min.right != None:
                        Minparent.left = Min.right
                    else:
                        Minparent.left = None

        self.insert(i,new_val)


    return i

# %% [markdown]
# # 流程圖

# %% [markdown]
# ![](https://i.imgur.com/jFxn5eK.jpg)

# %% [markdown]
# ![](https://i.imgur.com/q8BywJK.jpg)

# %% [markdown]
# ![](https://i.imgur.com/yfZjDDE.jpg)

# %% [markdown]
# ![](https://i.imgur.com/dTDyyS4.jpg)

# %% [markdown]
# ![](https://i.imgur.com/dWgnRqU.jpg)

# %% [markdown]
# ![](https://i.imgur.com/ropeHuC.jpg)

# %% [markdown]
# # 參考資料：
#
# search
#
# https://www.tutorialspoint.com/python_data_structure/python_binary_search_tree.htm
#
# delete
#
# https://www.geeksforgeeks.org/binary-search-tree-set-2-delete/
#
# https://www.twblogs.net/a/5d4e2980bd9eee541c310dd4
#
# https://www.itread01.com/content/1542339850.html
